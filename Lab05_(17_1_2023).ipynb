# %% [markdown]
# <a href="https://colab.research.google.com/github/Kawin101/935442-ImageProcessing/blob/main/Lab05_(17_1_2023).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

image = cv2.imread("/content/drive/MyDrive/รูปภาพและวิดีโอ/studentphoto.jfif", 0)

sobel = cv2.Sobel(image,cv2.CV_64F,1,1,ksize=5) # xy

plt.imshow(sobel, cmap="gray")

plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

image = cv2.imread("/content/drive/MyDrive/รูปภาพและวิดีโอ/studentphoto.jfif", 0)

#f = np.array([[1,1,1], [1,-4,1], [1,1,1]])
#f = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
f = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])

# print (f)
sharp = cv2.filter2D(image, -1, f)
plt.subplot(121),plt.imshow(image, cmap='gray')
plt.show
plt.subplot(122),plt.imshow(sharp, cmap='gray')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

image = cv2.imread("/content/drive/MyDrive/รูปภาพและวิดีโอ/studentphoto.jfif", 0)

blur = cv2.medianBlur(image, 5)

sharp = image - 0.4*blur
sharp[sharp>255] = 255

sharp[sharp<0] = 0

sharp = sharp.round().astype(np.uint8)

plt.subplot(121), plt.imshow(image, cmap="gray")
plt.subplot(122), plt.imshow(sharp,cmap="gray")

plt.show()
